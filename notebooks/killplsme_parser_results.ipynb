# %% [markdown]
# ### Выгрузка данных с сайта killpls.me

# %%
import pandas as pd

# %%
df = pd.read_csv('../output/killplsme_20211004-194643.csv', lineterminator='\n')

# %%
df.sample(30)
# Out:
#           id                     date                        tags  likes  \
# 14662  18747  27 сентября 2016, 14:00                     друзья    2318
# 19819  22130    22 апреля 2018, 20:00                      семья    2236
# 6862   13993       24 мая 2014, 05:00           семья , здоровье    4583
# 7755    7705  18 сентября 2011, 13:15                     друзья    6521
# 25208  28392     29 марта 2021, 10:00          семья , отношения    1884
# 12502  12967     3 ноября 2013, 17:00                     разное    6670
# 15880  18019       26 мая 2016, 12:00        здоровье , родители    3350
# 13862  21357   12 декабря 2017, 13:00        здоровье , родители    2490
# 4336    2576    2 февраля 2010, 18:19                      семья    1704
# 14946  18783    3 октября 2016, 16:00         разное , отношения    2417
# 23552  25398   25 октября 2019, 05:00  семья , родители , деньги    2851
# 2024    2247   25 декабря 2009, 00:28                  отношения    1568
# ...
