# %% [markdown]
# https://zvonili.com/

# %%
import pandas as pd

# %%
DF = '../output/zvonili-20211029-115453.csv'

# %%
df = pd.read_csv(DF)

# %%
df.shape
# Out:
# (441794, 6)

# %%
df.head(10)
# Out:
#        number  views                   tags  \
# 0  9623647868     62                Реклама
# 1  9003664119    199              Мошенники
# 2  9608774378    520  Мошенники, Неадекваты
# 3  9608774378    520  Мошенники, Неадекваты
# 4  9608774378    520  Мошенники, Неадекваты
# 5  9608774378    520  Мошенники, Неадекваты
# 6  9608774378    520  Мошенники, Неадекваты
# 7  9315421277     41             Неадекваты
# 8  9253647569    632               Хулиганы
# 9  9525153916    104                    NaN
#
#                                       company_region  \
# 0  \nОператор номера +7 (962) 364-78-68\n        ...
# 1  \nОператор номера +7 (900) 366-41-19\n        ...
# 2  \nОператор номера +7 (960) 877-43-78\n        ...
# 3  \nОператор номера +7 (960) 877-43-78\n        ...
# 4  \nОператор номера +7 (960) 877-43-78\n        ...
# 5  \nОператор номера +7 (960) 877-43-78\n        ...
# 6  \nОператор номера +7 (960) 877-43-78\n        ...
# ...

# %%
df.tail(10)
# Out:
#             number  views       tags  \
# 441784  9674596142    287  Мошенники
# 441785  9914638151    217        NaN
# 441786  4951549841     51  Мошенники
# 441787  4951549841     51  Мошенники
# 441788  9033493853    156  Мошенники
# 441789  9697985122    336        NaN
# 441790  9697985122    336        NaN
# 441791  9697985122    336        NaN
# 441792  4956789001     46        NaN
# 441793  9090691029     52  Мошенники
#
#                                            company_region  \
# 441784  \nОператор номера +7 (967) 459-61-42\n        ...
# 441785  \nОператор номера +7 (991) 463-81-51\n        ...
# 441786  \nОператор номера +7 (495) 154-98-41\n        ...
# 441787  \nОператор номера +7 (495) 154-98-41\n        ...
# 441788  \nОператор номера +7 (903) 349-38-53\n        ...
# 441789  \nОператор номера +7 (969) 798-51-22\n        ...
# 441790  \nОператор номера +7 (969) 798-51-22\n        ...
# 441791  \nОператор номера +7 (969) 798-51-22\n        ...
# ...

# %%
df.number.value_counts()
# Out:
# 9867257983    933
# 4957730527    734
# 8005557775    404
# 3952798587    386
# 8005339625    349
#              ...
# 9257790128      1
# 8482370227      1
# 9318889696      1
# 9176015545      1
# 9094307836      1
# Name: number, Length: 160438, dtype: int64
